# %%
def sum(num1,num2):
    print(f"the result of adding {num1} and {num2} is {num1+num2}")
def subs(num1,num2):
    print (f"the result of substracting {num1} and {num2} is {num1-num2}")
def mul(num1,num2):
    print (f"the result of multiplying {num1} and {num2} is {num1*num2}")
def div(num1,num2):
    print (f"the result of dividing {num1} and {num2} is {num1/num2}")

def nums():   
    global num1
    global num2 
      
    x=input("Enter the first number")
    y=input("Enter the second number")
    try:
        num1=float(x)
        num2=float(y)
    except:
        num1=float(input("invalid!! Enter the first number again"))
        num2=float(input("invalid!! Enter the second number again"))    
     
        
        
def operation():
    global op
    op=input("enter your operation (+) , (-) , (*) , (/) , (exit) ")
    
def op_is_add():
        sum(num1,num2)
        ask=input("Do you want to do another operation? yes / no")
        if ask=="yes":
            nums()
            operation()
            if op=="+":
                op_is_add()
                
            elif op=="-":
                op_is_sub()
                    
            elif op=="*":
                op_is_mul()

            elif op=="/":
                op_is_div() 

            elif op=="exit":
                exit 
            
            
        elif ask=="no":
            print("Thank you")
            exit
            
def op_is_sub():
        subs(num1,num2)
        ask=input("Do you want to do another operation? yes / no")
        if ask=="yes":
            nums()
            operation()

            if op=="+":
                op_is_add()
                
            elif op=="-":
                op_is_sub()
                    
            elif op=="*":
                op_is_mul()

            elif op=="/":
                op_is_div() 

            elif op=="exit":
                exit 
                
             
        elif ask=="no":
            print("Thank you")
            exit   
            
def op_is_mul():
        mul(num1,num2)
        ask=input("Do you want to do another operation? yes / no")
        if ask=="yes":
            nums()
            operation()
            if op=="+":
                op_is_add()
                
            elif op=="-":
                op_is_sub()
                    
            elif op=="*":
                op_is_mul()

            elif op=="/":
                op_is_div() 

            elif op=="exit":
                exit    
              
             
        elif ask=="no":
            print("Thank you")
            exit  

def op_is_div():
        if num2==0:
            print("invalid!! please enter another number instead of 0")
            nums()
            operation()
            op_is_div()     
           
        else:
            div(num1,num2)    
            ask=input("Do you want to do another operation? yes / no")
            if ask=="yes":
                nums()
                operation()
                if op=="+":
                    op_is_add()
                    
                elif op=="-":
                    op_is_sub()
                        
                elif op=="*":
                    op_is_mul()

                elif op=="/":
                    op_is_div() 

                elif op=="exit":
                    exit   
                
            elif ask=="no":
                print("Thank you")
                exit              
    
nums()
operation()

if op=="+":
  op_is_add()
  
elif op=="-":
  op_is_sub()
      
elif op=="*":
  op_is_mul()

elif op=="/":
  op_is_div() 

elif op=="exit":
    exit
# Out:
# the result of adding 5.0 and 5.0 is 10.0
# Thank you
